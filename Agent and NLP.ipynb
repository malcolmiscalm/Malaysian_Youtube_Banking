# %% [markdown]
# # Sentiment Analysis

# %%
from googletrans import Translator

translator = Translator()

async def translate_text(original_text: str):
    translation = await translator.translate(original_text, dest='en')
    translated_text, original_language = translation.text, translation.src
    return translated_text, original_language

# Run it
original_text = "این غذا خیلی شوره!"

my_translation = await translate_text("این غذا خیلی شوره!")
print(my_translation)
# Out:
# ('This food is very salty!', 'fa')

# %%
malay_translation = await translate_text("mak kau hijau lah")
print(malay_translation)
# Out:
# ('Your mother is green', 'ms')

# %% [markdown]
# ## Instantiate model, auxullary functions and first test

# %% [markdown]
# ```bash
# pip uninstall -y transformers tokenizers sentencepiece
# pip install transformers==4.45.1 tokenizers==0.20.3 sentencepiece
# ```

# %%
## Sanity check
from transformers import AutoTokenizer, AutoModelForSequenceClassification

MODEL = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

print("✅ Model and tokenizer loaded successfully!")
# Out:
# ✅ Model and tokenizer loaded successfully!

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig


MODEL = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
ROBERTA_SUPPORTED_LANGUAGES = ('ar', 'en', 'fr', 'de', 'hi', 'it', 'es', 'pt')

model = AutoModelForSequenceClassification.from_pretrained(MODEL)
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL, use_fast=False)

#/ save the model locally
model.save_pretrained(MODEL)
tokenizer.save_pretrained(MODEL)

ROBERTA_SUPPORTED_LANGUAGES = ('ar', 'en', 'fr', 'de', 'hi', 'it', 'es', 'pt')


# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

def predict_sentiment(text: str) -> str:
    processed_text = preprocess(text)
    encoded_input = tokenizer(processed_text, return_tensors='pt')
    output = model(**encoded_input)
    index_of_sentiment = output.logits.argmax().item()
    sentiment = config.id2label[index_of_sentiment]
    return sentiment

# 🧩 Sentiment prediction
import torch 
def predict_sentiment_2(text: str) -> str:
    processed_text = preprocess(text)
    # 🛡️ Tokenize safely
    encoded_input = tokenizer(
        processed_text,
        return_tensors='pt',
        truncation=True,         # <- prevent long text error
        max_length=512,          # <- enforce model limit
        padding=True
    )
    with torch.no_grad():
        output = model(**encoded_input)

    index_of_sentiment = output.logits.argmax().item()
    sentiment = config.id2label[index_of_sentiment]
    return sentiment

# %% [markdown]
# ## First test

# %%
text1 = "la pizza da @michele è veramente buona https://www.youtube.com"
text2 = "این غذا خیلی شوره!"
text3 = "یه جلسه دیگه که میتونست یه ایمیل باشه 🥲"
text4 = 'Yet another one bites the dust'


translation, source_language = await translate_text(text4)
print(predict_sentiment(translation))
# Out:
# negative

# %%
# Reading the file - unpickling from RDMS_1
import pickle
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 1000)
with open('./Data/COLLATE/COMMENT.pkl', 'rb') as fp:
    COLLATE_COMMENT = pickle.load(fp)
## Preview
print('COMMENT')
display(pd.concat([ COLLATE_COMMENT.head(2),  COLLATE_COMMENT.tail(2) ]))
display(COLLATE_COMMENT.dtypes)
# Out:
# COMMENT
#       Youtube_Video_IDs            poster_OP  comment_age  \
# 0           FmQz15WJkWE       @tinkerlee-r9z  3 weeks ago
# 1           zb3oKcLv1yA     @kayanemahberkah  1 month ago
# 15446       4tA8wtLaui4           @JokeRQuas  7 years ago
# 15447       gA0hQtE6TL4  @floristdahlins8520  9 years ago
#
#                                                                                                               full_comment  \
# 0      BECAREFUL WHAT YOU WISH FOR   -  CIRCUS   ???!  | Ale Duke 2.0  Living in America - James Brown 1985 |   -  YouTube
# 1                                                           kak cara pindahin ocbc mobile dari hp lama ke hp baru gimna ya
# 15446                                                                                                                    .
# 15447                                                                                                                    ,
#
#        like_count Youtube_Handle
# 0               0            NaN
# 1               0            NaN
# 15446           0           @uob
# 15447           0           @uob
# Youtube_Video_IDs    object
# poster_OP            object
# comment_age          object
# full_comment         object
# like_count            int64
# Youtube_Handle       object
# dtype: object

# %%
COLLATE_COMMENT[COLLATE_COMMENT.Youtube_Handle.isna()].iloc[:5, :]
# Out:
#   Youtube_Video_IDs           poster_OP   comment_age  \
# 0       FmQz15WJkWE      @tinkerlee-r9z   3 weeks ago
# 1       zb3oKcLv1yA    @kayanemahberkah   1 month ago
# 2       Y6GQJUyjDO4  @VikkiNesspara-f2u   1 month ago
# 3       GGbcl2AcSBU      @RisNandar-c9h  2 months ago
# 4       meamip7zfzI          @BozuBoyYT   11 days ago
#
#                                                                                                              full_comment  \
# 0     BECAREFUL WHAT YOU WISH FOR   -  CIRCUS   ???!  | Ale Duke 2.0  Living in America - James Brown 1985 |   -  YouTube
# 1                                                          kak cara pindahin ocbc mobile dari hp lama ke hp baru gimna ya
# 2  happy 60th birthday Singapore 🇸🇬🇸🇬🇸🇬️🇸🇬️️🇸🇬️🇸🇬️🇸🇬️️🇸🇬️️🇸🇬️🇸🇬️ 🎇 🎇 🦁 🎆 🎆 🦁 ❤ ❤ 🕊 🕊 ✌🏾 ✌🏾 👉🏾 ❤ ❤ 🌏 👈🏾 ❤ ❤ 🕊 🕊 ✌🏾 ✌🏾 🙋🏾‍♀
# 3                                                                                                               OCBC  ❤ ❤
# 4                                                                             The person doing the voice over is so good!
#
#    like_count Youtube_Handle
# 0           0            NaN
# 1           0            NaN
# 2           0            NaN
# 3           0            NaN
# 4           2            NaN

# %%
COLLATE_COMMENT.fillna({'Youtube_Handle' : '@channelocbc'}, inplace=True)

# %% [markdown]
# ## Translate text and detect languages

# %%
import pandas as pd
import asyncio
from googletrans import Translator

translator = Translator()

async def translate_text(original_text: str):
    translation = await translator.translate(original_text, dest='en')
    return translation.text, translation.src

async def translate_series(series):
    tasks = [translate_text(text) for text in series]
    results = await asyncio.gather(*tasks)
    return results

# Run all translations asynchronously
results = await translate_series(COLLATE_COMMENT['full_comment'])
COLLATE_COMMENT[['translated_text', 'detected_lang']] = pd.DataFrame(results, columns=['translated_text', 'detected_lang'])

# %%
# View non-english comments
COLLATE_COMMENT[COLLATE_COMMENT['detected_lang'] != 'en']
# Out:
#                      Youtube_Video_IDs         poster_OP   comment_age  \
# 1                          zb3oKcLv1yA  @kayanemahberkah   1 month ago
# 21                         eO3mGG3x3E8   @AgnesWong-0924  5 months ago
# 23                         eO3mGG3x3E8     @TommyChu-p7o  5 months ago
# 24                         9C_UyZJQ0Vg  @CharlieWuGunpla  5 months ago
# 25                         TF6ebsFMY_M   @pohchoopeh4225  5 months ago
# ...                                ...               ...           ...
# 15392                      AkxPA5mFjeI        @dctam9725   5 years ago
# 15393                      AkxPA5mFjeI  @HoangTranCoffee   6 years ago
# 15394                      AkxPA5mFjeI   @hoanglengoc130   5 years ago
# 15406  4rMqRXRBGzQ&pp=0gcJCQYKAYcqIYzv    @sainikhan6530   5 years ago
# 15428                      4tA8wtLaui4         @karlafvs   7 years ago
#
#                                                                                                                    full_comment  \
# 1                                                                kak cara pindahin ocbc mobile dari hp lama ke hp baru gimna ya
# 21                                                                                               好正向，阿V嘅表演真係好有吸引力 繼續enjoy人生 ❤ 😊
# 23                                                                                                                  原來阿V過去有咁嘅經歷
# 24                                                                                                                香港電影業靠你啦！你得嘅！
# 25                                                                                                                  所以上网付款最危险 😮
# ...                                                                                                                         ...
# 15392                                                                                 Hồ sơ gồm những gì ah?  Lãi suất thế nào?
# 15393  Shop mở kho hàng tại HCM, nhưng xưởng sản xuất tại Kon Tum, Hộ Kinh Doanh đăng ký tại Kon Tum,  thì có được vay không ạ?
# 15394                                                                                                 Chỉ áp dụng cho tphcm ạ??
# 15406                                                                                                                     Susah
# 15428                                                                                                    bello bello. BRUU TAL!
#
#        like_count Youtube_Handle  \
# 1               0   @channelocbc
# 21              0   @channelocbc
# 23              0   @channelocbc
# 24              0   @channelocbc
# 25              0   @channelocbc
# ...           ...            ...
# 15392           0           @uob
# 15393           0           @uob
# 15394           0           @uob
# 15406           0           @uob
# 15428           0           @uob
#
#                                                                                                                             translated_text  \
# 1                                                                  Sis, how do I move OCBC Mobile from an old cellphone to a new cellphone?
# 21                                                       It's awesome, Ah V's performance is really attractive to continue to enjoy life ❤😊
# 23                                                                            It turns out that Ah V has had such an experience in the past
# 24                                                                                     The Hong Kong film industry depends on you! You can!
# 25                                                                                                So online payment is the most dangerous 😮
# ...                                                                                                                                     ...
# 15392                                                                             What does the profile include?  What's the interest rate?
# 15393  The shop opens a warehouse in HCM, but the factory is in Kon Tum, and the Business House is registered in Kon Tum, can I get a loan?
# 15394                                                                                                    Only applies to Ho Chi Minh City??
# 15406                                                                                                                             Difficult
# 15428                                                                                                         beautiful beautiful. BRUU SO!
#
#       detected_lang
# 1                id
# 21              yue
# 23              yue
# 24              yue
# 25            zh-CN
# ...             ...
# 15392            vi
# 15393            vi
# 15394            vi
# 15406            ms
# 15428            it
#
# [6143 rows x 8 columns]

# %% [markdown]
# ## Infer sentiment

# %%
import time
start = time.time()
sentiment_results = COLLATE_COMMENT['translated_text'].apply(predict_sentiment_2)
COLLATE_COMMENT['sentiment'] = pd.Series(sentiment_results)
print("⏱️ Elapsed:", time.time() - start, "seconds")
# Out:
# ⏱️ Elapsed: 800.3586339950562 seconds

# %%
# Write into COLLATE folder
with open('./Data/COLLATE/COMMENT_sentiment.pkl', 'wb') as f:
    pickle.dump(COLLATE_COMMENT, f)

# %% [markdown]
# # RDMS_2
# > Recreate a new databse in `"./Data/RDBMS/malaysian_youtube_banks_sentiment_deduplicated.db"`

# %%
## Read back data
# Takes a while to read the pickle
import pickle
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 1000)
# Reading the file - unpickling
with open('./Data/abm_banks_malaysia.pkl', 'rb') as fp:
    abm_banks_df = pickle.load(fp)
## Preview

display(pd.concat([ abm_banks_df.head(1),  abm_banks_df.tail(1) ]))
print('ABM_table')
display(pd.DataFrame(abm_banks_df.dtypes, columns=['datatype']))
# Out:
#                              Bank_Names                          Hashtag_Name  \
# 0                     Affin Bank Berhad                    #affin_bank_berhad
# 25  United Overseas Bank (Malaysia) Bhd  #united_overseas_bank_(malaysia)_bhd
#
#                           Top_Person  Top_Title  \
# 0   Datuk Wan Razly Abdullah Wan Ali  Group CEO
# 25                        Ng Wei Wei        CEO
#
#                                     Bank_Website Youtube_Handle
# 0   https://www.affingroup.com/affin-bank-berhad         @AFFIN
# 25                        http://www.uob.com.my/           @uob
# ABM_table
#                datatype
# Bank_Names       object
# Hashtag_Name     object
# Top_Person       object
# Top_Title        object
# Bank_Website     object
# Youtube_Handle   object

# %%
# Reading the file - unpickling
with open('./Data/overview_youtube_2.pkl', 'rb') as fp:
    overview_df = pickle.load(fp) # New and improved 
## Preview

display(pd.concat([ overview_df.head(1),  overview_df.tail(1) ]))
print('Overview_table')
display(pd.DataFrame(overview_df.dtypes, columns=['datatype']))
display(overview_df.shape)
# Out:
#         ID mail           Scraped_DateTime phone                language  \
# 0   @AFFIN      2025-10-23 19:19:33.602173        www.youtube.com/@AFFIN
# 23    @uob      2025-10-23 19:26:02.841470          www.youtube.com/@uob
#
#    privacy_public        info_outline       person_radar     my_videos  \
# 0        Malaysia  Joined 18 Jun 2014   4.9K subscribers    325 videos
# 23      Singapore  Joined 24 Nov 2012  29.2K subscribers  1,286 videos
#
#     Videos_Not_Shorts       trending_up
# 0                 221  15,050,294 views
# 23               1210  86,088,593 views
# Overview_table
#                          datatype
# ID                         object
# mail                       object
# Scraped_DateTime   datetime64[ns]
# phone                      object
# language                   object
# privacy_public             object
# info_outline               object
# person_radar               object
# my_videos                  object
# Videos_Not_Shorts           int64
# trending_up                object
# (24, 11)

# %%
# Reading the file - unpickling
with open('./Data/COLLATE/MM.pkl', 'rb') as fp:
    COLLATE_MM = pickle.load(fp)
## Preview
display(pd.concat([ COLLATE_MM.iloc[[150],:],  COLLATE_MM.tail(1) ]))
print('MM_table')
display(pd.DataFrame(COLLATE_MM.dtypes, columns=['datatype']))
display(COLLATE_MM.shape)
# Out:
#       Youtube_Video_IDs    Youtube_Handle video_length   views       date  \
# 150         83LznfQ1aHI      @channelocbc         0:52   262.0 2024-08-29
# 15908       tew6Ly8NDcc  @MUFGBankChannel         4:50  3859.0 2019-08-12
#
#                                   title  likes  \
# 150    A fresh twist on your favourites    5.0
# 15908            動画で学ぶ資産運用「つみたて投資によろしく」    0.0
#
#                                                                                                                             description  \
# 150    We have given your favourite features a makeover. Here is a smoother, more intuitive OCBC app experience.\n#ocbcbank\n\n#ocbcapp
# 15908                                                                                       No description has been added to this video
#
#              MM_timestamp is_commented
# 150   2025-11-04 15:03:07         True
# 15908 2025-11-03 16:49:01         None
# MM_table
#                          datatype
# Youtube_Video_IDs          object
# Youtube_Handle             object
# video_length               object
# views                     float64
# date               datetime64[ns]
# title                      object
# likes                     float64
# description                object
# MM_timestamp       datetime64[ns]
# is_commented               object
# (15909, 10)

# %%
# Reading the file - unpickling - what have just done in Sentiment Analysis above.
with open('./Data/COLLATE/COMMENT_sentiment.pkl', 'rb') as fp:
    COLLATE_COMMENT = pickle.load(fp)
## Preview

display(pd.concat([ COLLATE_COMMENT.head(2),  COLLATE_COMMENT.iloc[[15000],:]]))
print('COMMENT_table')
display(pd.DataFrame(COLLATE_COMMENT.dtypes, columns=['datatype']))
display(COLLATE_COMMENT.shape)
# Out:
#       Youtube_Video_IDs         poster_OP  comment_age  \
# 0           FmQz15WJkWE    @tinkerlee-r9z  3 weeks ago
# 1           zb3oKcLv1yA  @kayanemahberkah  1 month ago
# 15000       oWyumLYSe6Q   @LisaWalker-f8b   1 year ago
#
#                                                                                                               full_comment  \
# 0      BECAREFUL WHAT YOU WISH FOR   -  CIRCUS   ???!  | Ale Duke 2.0  Living in America - James Brown 1985 |   -  YouTube
# 1                                                           kak cara pindahin ocbc mobile dari hp lama ke hp baru gimna ya
# 15000                                                                                                       Geoffrey Light
#
#        like_count Youtube_Handle  \
# 0               0   @channelocbc
# 1               0   @channelocbc
# 15000           0           @uob
#
#                                                                                                            translated_text  \
# 0      BECAREFUL WHAT YOU WISH FOR   -  CIRCUS   ???!  | Ale Duke 2.0  Living in America - James Brown 1985 |   -  YouTube
# 1                                                 Sis, how do I move OCBC Mobile from an old cellphone to a new cellphone?
# 15000                                                                                                       Geoffrey Light
#
#       detected_lang sentiment
# 0                en   neutral
# 1                id   neutral
# 15000            en   neutral
# COMMENT_table
#                   datatype
# Youtube_Video_IDs   object
# poster_OP           object
# comment_age         object
# full_comment        object
# like_count           int64
# Youtube_Handle      object
# translated_text     object
# detected_lang       object
# sentiment           object
# (15448, 9)

# %%
# Ensure all unique
print(len(COLLATE_MM['Youtube_Video_IDs']) == COLLATE_MM['Youtube_Video_IDs'].nunique())
# Show any duplicates - duplicates might showed up for Private Videos
bool_series = COLLATE_MM.duplicated(subset=['Youtube_Video_IDs'], keep=False)
display(COLLATE_MM[bool_series])
# Remove the dulicates, keep first instance
COLLATE_MM.drop_duplicates(subset=['Youtube_Video_IDs'], keep='first', inplace=True)
# Out:
# True
# Empty DataFrame
# Columns: [Youtube_Video_IDs, Youtube_Handle, video_length, views, date, title, likes, description, MM_timestamp, is_commented]
# Index: []

# %%
# Ensure all unique
print(len(COLLATE_COMMENT['Youtube_Video_IDs']) == len(set(COLLATE_COMMENT['Youtube_Video_IDs'])))
# Show any duplicates - duplicates might showed up the key below
duplicate_combo_key = ['Youtube_Video_IDs', 'poster_OP','full_comment', 'like_count']
bool_series = COLLATE_COMMENT.duplicated(subset=duplicate_combo_key, keep=False)
display(COLLATE_COMMENT[bool_series])
# Remove the dulicates, keep first instance
COLLATE_COMMENT.drop_duplicates(subset=duplicate_combo_key, keep='first', inplace=True)

## Write de-duplicated
# Write into COLLATE folder
with open('./Data/COLLATE/COMMENT_sentiment_deduplicated.pkl', 'wb') as f:
    pickle.dump(COLLATE_COMMENT, f)
# Out:
# False
#                      Youtube_Video_IDs                        poster_OP  \
# 135    HJ5YwHq3O_c&pp=0gcJCQYKAYcqIYzv                       @Zam-ms7xs
# 136    HJ5YwHq3O_c&pp=0gcJCQYKAYcqIYzv                       @Zam-ms7xs
# 511                        sMEKjQbwUBc       @patriciavanderpoorten4102
# 512                        sMEKjQbwUBc       @patriciavanderpoorten4102
# 594                        vhCwaV4LMZU                    @NadineBerton
# 595                        vhCwaV4LMZU                    @NadineBerton
# 1183                       Fkw-x7bOCdE                 @AdrienneGrellet
# 1184                       Fkw-x7bOCdE                 @AdrienneGrellet
# 1207                       rtlVd9UQl88                 @benedicteho4584
# 1214                       rtlVd9UQl88                    @anniedel9988
# 1219                       rtlVd9UQl88                 @benedicteho4584
# 1220                       rtlVd9UQl88                    @anniedel9988
# 1759                       xZUQBw_ORk0           @mohendrasooknanan2870
# 1761                       xZUQBw_ORk0           @mohendrasooknanan2870
# 1941                       BmV6Y0TGCCo                     11 years ago
# 1942                       BmV6Y0TGCCo                     11 years ago
# 1958                       -lFnOcR-d48                     @DJ_FoX_1949
# 1960                       -lFnOcR-d48                     @DJ_FoX_1949
# 2453   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                      @msteng1598
# 2454   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                      @msteng1598
# 2553   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                    @mazralialway
# 2554   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                    @mazralialway
# 2571   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                    @haznitahusin
# 2572   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                    @haznitahusin
# 2664   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                       @Randoms1R
# 2665   Jxq0sBCIkJI&pp=0gcJCQYKAYcqIYzv                       @Randoms1R
# 2721                       a2Q6acQIPDs                     @aranperumal
# 2722                       a2Q6acQIPDs                     @aranperumal
# 3017                       4TC61y9R2EI                   @YvonneLim-k2c
# 3036                       4TC61y9R2EI                   @JaiNordin-o4f
# 3037                       4TC61y9R2EI                   @YvonneLim-k2c
# 3049                       4TC61y9R2EI     @indihjbasriwydydu4hy36dyee8
# 3056                       4TC61y9R2EI                   @YvonneLim-k2c
# 3063                       4TC61y9R2EI                   @YvonneLim-k2c
# 3064                       4TC61y9R2EI                   @JaiNordin-o4f
# 3067                       4TC61y9R2EI     @indihjbasriwydydu4hy36dyee8
# 3069                       4TC61y9R2EI                   @YvonneLim-k2c
# 3071                       4TC61y9R2EI                   @JaiNordin-o4f
# 3072                       4TC61y9R2EI                     @SitiLia-e5v
# 3073                       4TC61y9R2EI     @indihjbasriwydydu4hy36dyee8
# 3074                       4TC61y9R2EI                   @YvonneLim-k2c
# 3076                       4TC61y9R2EI                     @SitiLia-e5v
# 3077                       4TC61y9R2EI     @indihjbasriwydydu4hy36dyee8
# 3078                       4TC61y9R2EI                   @YvonneLim-k2c
# 3081                       4TC61y9R2EI     @indihjbasriwydydu4hy36dyee8
# 3122                       f97-rmmUSTc           @TiffanyLafuente-du4ju
# 3125                       f97-rmmUSTc           @TiffanyLafuente-du4ju
# 3126                       f97-rmmUSTc           @TiffanyLafuente-du4ju
# 3218                       pLC8UZcqUZU                     @kaoridaho23
# 3227                       pLC8UZcqUZU                     @kaoridaho23
# 3249                       lOT8MnX4Qjw                  @krishnaRao-y1d
# 3250                       lOT8MnX4Qjw                  @krishnaRao-y1d
# 3456                       RJgYa5VU3-g               @sitinuraisyah3183
# 3630                       RJgYa5VU3-g               @sitinuraisyah3183
# 3646                       9CsRuccA83Q             @maizatulsaaudah8266
# 3649                       9CsRuccA83Q             @maizatulsaaudah8266
# 4770   HtiExpvEmKo&pp=0gcJCQYKAYcqIYzv                  @noorazizah9138
# 4771   HtiExpvEmKo&pp=0gcJCQYKAYcqIYzv                  @noorazizah9138
# 4989                       cfVdY3Yb-HM                  @asrieeelie5678
# 5053                       cfVdY3Yb-HM                  @asrieeelie5678
# 5276                       IdlE-C_vJCM                   @teleport_link
# 5277                       IdlE-C_vJCM                   @teleport_link
# 5278                       IdlE-C_vJCM                   @teleport_link
# 5279                       IdlE-C_vJCM                   @teleport_link
# 5280                       IdlE-C_vJCM                   @teleport_link
# 5282                       IdlE-C_vJCM                   @teleport_link
# 5283                       IdlE-C_vJCM                   @teleport_link
# 5309                       IdlE-C_vJCM            @norazrinatukiman2064
# 5310                       IdlE-C_vJCM            @norazrinatukiman2064
# 5451                       oqKzWSdSMe8                @anafalaviana9068
# 5460                       oqKzWSdSMe8                @anafalaviana9068
# 5752                       _nK_24F9sfM               @AbdulRehman-o3g8o
# 5753                       _nK_24F9sfM               @AbdulRehman-o3g8o
# 5754                       _nK_24F9sfM               @AbdulRehman-o3g8o
# 5755                       _nK_24F9sfM               @AbdulRehman-o3g8o
# 5951   WwVw96cRqHY&pp=0gcJCQYKAYcqIYzv                     @KishinNiger
# 5958   WwVw96cRqHY&pp=0gcJCQYKAYcqIYzv                     @KishinNiger
# 5987                       k5ouo1vhnPU          @KevindanielVargaslopez
# 6030                       k5ouo1vhnPU          @KevindanielVargaslopez
# 6087                       Oca5vDdAaAE                   @YMTSDNE5V2S6G
# 6089                       Oca5vDdAaAE                   @YMTSDNE5V2S6G
# 6408                       30keMq4qudY                @fabiuskumgne3659
# 6409                       30keMq4qudY                @fabiuskumgne3659
# 6441                       jl7S3joHMCY                    @katebohn5061
# 6453                       jl7S3joHMCY                    @katebohn5061
# 7818                       JgavF-hINXM                 @hoPpsWanChi6322
# 7822                       JgavF-hINXM                 @hoPpsWanChi6322
# 7882   kGT---8btXs&pp=0gcJCQYKAYcqIYzv                    @MonoBairagee
# 7888   kGT---8btXs&pp=0gcJCQYKAYcqIYzv                    @MonoBairagee
# 8057                       M6q9zyKtaPE         @dinmuhammadchaudary7659
# 8061                       M6q9zyKtaPE         @dinmuhammadchaudary7659
# 8626                       mZ-4Uy4s4OE                 @ambilykushal185
# 8627                       mZ-4Uy4s4OE                 @ambilykushal185
# 8928                       DTzDycy4lsQ                @dannymusonda1520
# 8934                       DTzDycy4lsQ                @dannymusonda1520
# 8992                       h2OI6IjXhLY               @thunderdemonlover
# 8999                       h2OI6IjXhLY               @thunderdemonlover
# 9096                       WvXWAiMikXw                @merygrisales3069
# 9097                       WvXWAiMikXw                @merygrisales3069
# 9135                       ETtNJpfTJRM        @pankajkumarchoudhary4770
# 9137                       ETtNJpfTJRM        @pankajkumarchoudhary4770
# 9139                       hsyhsDobB_s                  @arjunjatav1859
# 9140                       hsyhsDobB_s                  @arjunjatav1859
# 9142                       hsyhsDobB_s                  @arjunjatav1859
# 9143                       hsyhsDobB_s                  @arjunjatav1859
# 9169                       JX_PIDq0ECM                   @MdRehan-su6fn
# 9172                       JX_PIDq0ECM                   @MdRehan-su6fn
# 9173                       JX_PIDq0ECM                   @MdRehan-su6fn
# 9197                       VW-7P8VCZAY            @yellanollanagesh8454
# 9198                       VW-7P8VCZAY            @yellanollanagesh8454
# 9345                       75CFj0bM6Ao                    @SomaKhan-w9y
# 9348                       75CFj0bM6Ao                    @SomaKhan-w9y
# 10020                      O4fSZWpjcss                  @nabeihishak930
# 10021                      O4fSZWpjcss                  @nabeihishak930
# 10269                      8SwA-paRcLk                     @UjiAstamuji
# 10294                      8SwA-paRcLk                     @UjiAstamuji
# 10690  zRV55LyAOFo&pp=0gcJCQYKAYcqIYzv                 @asrimustafa1335
# 10691  zRV55LyAOFo&pp=0gcJCQYKAYcqIYzv                 @asrimustafa1335
# 10692  zRV55LyAOFo&pp=0gcJCQYKAYcqIYzv                 @asrimustafa1335
# 10693  zRV55LyAOFo&pp=0gcJCQYKAYcqIYzv                 @asrimustafa1335
# 12159                      7EjWmpvUZFA                       @joeyraizo
# 12165                      7EjWmpvUZFA                       @joeyraizo
# 12535  lVolSNrQVdQ&pp=0gcJCQYKAYcqIYzv              @kumarankumaran7357
# 12536  lVolSNrQVdQ&pp=0gcJCQYKAYcqIYzv              @kumarankumaran7357
# 12537                      pFRkqtcl_BY           @chokentertainment4379
# 12538                      pFRkqtcl_BY           @chokentertainment4379
# 12539                      pFRkqtcl_BY           @chokentertainment4379
# 12541                      psY67DFYhe8           @chokentertainment4379
# 12542                      psY67DFYhe8           @chokentertainment4379
# 12543                      psY67DFYhe8           @chokentertainment4379
# 12544                      psY67DFYhe8           @chokentertainment4379
# 12545                      psY67DFYhe8           @chokentertainment4379
# 12546                      psY67DFYhe8           @chokentertainment4379
# 12547                      psY67DFYhe8           @chokentertainment4379
# 12570                      Q_XScDAxbCY     @scryptoolzonigisthebest4947
# 12571                      Q_XScDAxbCY  @spoonertoolzsendhimatexton7068
# 12572                      Q_XScDAxbCY     @writeSCRYPTOOLZVIAINSTAGRAM
# 12573                      Q_XScDAxbCY             @scrpytoolzigram6641
# 12579                      Q_XScDAxbCY     @scryptoolzonigisthebest4947
# 12580                      Q_XScDAxbCY  @spoonertoolzsendhimatexton7068
# 12581                      Q_XScDAxbCY     @writeSCRYPTOOLZVIAINSTAGRAM
# 12582                      Q_XScDAxbCY             @scrpytoolzigram6641
# 12733                      hxtScn_nFiY                        @QQ-vg9jl
# 12781                      hxtScn_nFiY                        @QQ-vg9jl
# 12866                      JQ_ds9S9DPU          @madizulaikkasyamin3953
# 12941                      JQ_ds9S9DPU          @madizulaikkasyamin3953
# 14950                      Bn3rpiXCs8c                 @thuyphamthi7379
# 14955                      Bn3rpiXCs8c                 @thuyphamthi7379
# 15289                      6vG2eMzckxY                   @tankalvin7559
# 15305                      6vG2eMzckxY                   @tankalvin7559
#
#                                                                                                                                  comment_age  \
# 135                                                                                                                              5 years ago
# 136                                                                                                                              5 years ago
# 511                                                                                                                             6 months ago
# 512                                                                                                                             6 months ago
# 594                                                                                                                             8 months ago
# 595                                                                                                                             8 months ago
# 1183                                                                                                                           10 months ago
# 1184                                                                                                                           10 months ago
# 1207                                                                                                                              1 year ago
# 1214                                                                                                                             4 years ago
# 1219                                                                                                                              1 year ago
# 1220                                                                                                                             4 years ago
# 1759                                                                                                                             9 years ago
# 1761                                                                                                                             9 years ago
# 1941                                                                                                           Notre site www.bidulandco.com
# 1942   Nos clés USB pour iPhone et iPad sont disponibles sur Amazon, PriceMinister, Fnac.com, et sur notre boutique online www.bidulshop.com
# 1958                                                                                                                             4 years ago
# 1960                                                                                                                             4 years ago
# 2453                                                                                                                            2 months ago
# 2454                                                                                                                            2 months ago
# 2553                                                                                                                            2 months ago
# 2554                                                                                                                            2 months ago
# 2571                                                                                                                            2 months ago
# 2572                                                                                                                            2 months ago
# 2664                                                                                                                             1 month ago
# 2665                                                                                                                             1 month ago
# 2721                                                                                                                            5 months ago
# 2722                                                                                                                            5 months ago
# 3017                                                                                                                              1 year ago
# 3036                                                                                                                              1 year ago
# 3037                                                                                                                              1 year ago
# 3049                                                                                                                           11 months ago
# 3056                                                                                                                              1 year ago
# 3063                                                                                                                              1 year ago
# 3064                                                                                                                              1 year ago
# 3067                                                                                                                           11 months ago
# 3069                                                                                                                              1 year ago
# 3071                                                                                                                              1 year ago
# 3072                                                                                                                              1 year ago
# 3073                                                                                                                           11 months ago
# 3074                                                                                                                              1 year ago
# 3076                                                                                                                              1 year ago
# 3077                                                                                                                           11 months ago
# 3078                                                                                                                              1 year ago
# 3081                                                                                                                           11 months ago
# 3122                                                                                                                              1 year ago
# 3125                                                                                                                              1 year ago
# 3126                                                                                                                              1 year ago
# 3218                                                                                                                             2 years ago
# 3227                                                                                                                             2 years ago
# 3249                                                                                                                             2 years ago
# 3250                                                                                                                             2 years ago
# 3456                                                                                                                             2 years ago
# 3630                                                                                                                             2 years ago
# 3646                                                                                                                             2 years ago
# 3649                                                                                                                             2 years ago
# 4770                                                                                                                             7 years ago
# 4771                                                                                                                             7 years ago
# 4989                                                                                                                             7 years ago
# 5053                                                                                                                             7 years ago
# 5276                                                                                                                             7 years ago
# 5277                                                                                                                             7 years ago
# 5278                                                                                                                             7 years ago
# 5279                                                                                                                             7 years ago
# 5280                                                                                                                             7 years ago
# 5282                                                                                                                             7 years ago
# 5283                                                                                                                             7 years ago
# 5309                                                                                                                             7 years ago
# 5310                                                                                                                             7 years ago
# 5451                                                                                                                             7 years ago
# 5460                                                                                                                             7 years ago
# 5752                                                                                                                             2 weeks ago
# 5753                                                                                                                             2 weeks ago
# 5754                                                                                                                             2 weeks ago
# 5755                                                                                                                             2 weeks ago
# 5951                                                                                                                            3 months ago
# 5958                                                                                                                            3 months ago
# 5987                                                                                                                            3 months ago
# 6030                                                                                                                            3 months ago
# 6087                                                                                                                              1 year ago
# 6089                                                                                                                              1 year ago
# 6408                                                                                                                             4 years ago
# 6409                                                                                                                             4 years ago
# 6441                                                                                                                             3 years ago
# 6453                                                                                                                             3 years ago
# 7818                                                                                                                              1 year ago
# 7822                                                                                                                              1 year ago
# 7882                                                                                                                              1 year ago
# 7888                                                                                                                              1 year ago
# 8057                                                                                                                             2 years ago
# 8061                                                                                                                             2 years ago
# 8626                                                                                                                             3 years ago
# 8627                                                                                                                             3 years ago
# 8928                                                                                                                             5 years ago
# 8934                                                                                                                             5 years ago
# 8992                                                                                                                              1 year ago
# 8999                                                                                                                              1 year ago
# 9096                                                                                                                             8 years ago
# 9097                                                                                                                             8 years ago
# 9135                                                                                                                             9 years ago
# 9137                                                                                                                             9 years ago
# 9139                                                                                                                             9 years ago
# 9140                                                                                                                             9 years ago
# 9142                                                                                                                             9 years ago
# 9143                                                                                                                             9 years ago
# 9169                                                                                                                             9 years ago
# 9172                                                                                                                             9 years ago
# 9173                                                                                                                             9 years ago
# 9197                                                                                                                             9 years ago
# 9198                                                                                                                             9 years ago
# 9345                                                                                                                            5 months ago
# 9348                                                                                                                            5 months ago
# 10020                                                                                                                             1 year ago
# 10021                                                                                                                             1 year ago
# 10269                                                                                                                             1 year ago
# 10294                                                                                                                             1 year ago
# 10690                                                                                                                            3 years ago
# 10691                                                                                                                            3 years ago
# 10692                                                                                                                            3 years ago
# 10693                                                                                                                            3 years ago
# 12159                                                                                                                           11 years ago
# 12165                                                                                                                           11 years ago
# 12535                                                                                                                            2 years ago
# 12536                                                                                                                            2 years ago
# 12537                                                                                                                            4 years ago
# 12538                                                                                                                            4 years ago
# 12539                                                                                                                            4 years ago
# 12541                                                                                                                            4 years ago
# 12542                                                                                                                            4 years ago
# 12543                                                                                                                            4 years ago
# 12544                                                                                                                            4 years ago
# 12545                                                                                                                            4 years ago
# 12546                                                                                                                            4 years ago
# 12547                                                                                                                            4 years ago
# 12570                                                                                                                            4 years ago
# 12571                                                                                                                            4 years ago
# 12572                                                                                                                            4 years ago
# 12573                                                                                                                            4 years ago
# 12579                                                                                                                            4 years ago
# 12580                                                                                                                            4 years ago
# 12581                                                                                                                            4 years ago
# 12582                                                                                                                            4 years ago
# 12733                                                                                                                            5 years ago
# 12781                                                                                                                            5 years ago
# 12866                                                                                                                            5 years ago
# 12941                                                                                                                            5 years ago
# 14950                                                                                                                            1 month ago
# 14955                                                                                                                            1 month ago
# 15289                                                                                                                            2 years ago
# 15305                                                                                                                            2 years ago
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    full_comment  \
# 135                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Reset paswoand bsn
# 136                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Reset paswoand bsn
# 511                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Profi rechercher
# 512                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Profi rechercher
# 594                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              je n'arrive pas à vous joindre
# ...
# 12941                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Of
# 14950  It’s 11 p.m. and I’m shaking with anger reading this email. Since when did a bank’s mistake get twisted into being the customer’s fault? When I called the bank to ask how much I needed to pay to cancel my card, each staff member quoted a different amount. When I went to the branch to pay, they told me another number. Then when there was an overpayment, they told me to come and collect the excess. And now the email says that it was me who requested to take the money back, and that the staff just “followed instructions”? How on earth am I supposed to know the exact odd cents of the overpayment to even request a refund? The staff member at the counter had to check and calculate everything before finally telling me, “You’ve overpaid; let me help you get the refund.” Doesn’t the bank have cameras? Why don’t they review the footage instead of blaming the customer? This is ridiculous. I’ve already paid off the card to cancel it, and yet now they’re telling me I still owe money and that I’m overdue? How? I paid the full amount and even overpaid. Why am I now in debt and marked overdue? Even the staff member admitted that many customers are experiencing the same issue. Yet UOB still twists things around and sends emails blaming the customer. UOB itself gave the payment amount for card cancellation. I paid exactly that at the time, received the cancellation paper, and even had a surplus. How can there suddenly be an outstanding balance leading to overdue status? Doesn’t the bank see how unreasonable this is? When I call to resolve it, all they say is “That’s our policy.” Which policy exactly? Or is it just poor internal processes being blamed on customers? I already canceled the card and still had an overpayment. Even your sales rep commented, “Why did you pay so much?” and reminded me to come and collect the surplus. Over a week later, I finally went to pick up my refund. How am I supposed to know the exact amount? You’re the ones looking at the screen and calculating, not me. UOB even transferred the surplus back to me. And now I’m still listed as owing money and overdue? How does that make sense? Read more
# 14955  It’s 11 p.m. and I’m shaking with anger reading this email. Since when did a bank’s mistake get twisted into being the customer’s fault? When I called the bank to ask how much I needed to pay to cancel my card, each staff member quoted a different amount. When I went to the branch to pay, they told me another number. Then when there was an overpayment, they told me to come and collect the excess. And now the email says that it was me who requested to take the money back, and that the staff just “followed instructions”? How on earth am I supposed to know the exact odd cents of the overpayment to even request a refund? The staff member at the counter had to check and calculate everything before finally telling me, “You’ve overpaid; let me help you get the refund.” Doesn’t the bank have cameras? Why don’t they review the footage instead of blaming the customer? This is ridiculous. I’ve already paid off the card to cancel it, and yet now they’re telling me I still owe money and that I’m overdue? How? I paid the full amount and even overpaid. Why am I now in debt and marked overdue? Even the staff member admitted that many customers are experiencing the same issue. Yet UOB still twists things around and sends emails blaming the customer. UOB itself gave the payment amount for card cancellation. I paid exactly that at the time, received the cancellation paper, and even had a surplus. How can there suddenly be an outstanding balance leading to overdue status? Doesn’t the bank see how unreasonable this is? When I call to resolve it, all they say is “That’s our policy.” Which policy exactly? Or is it just poor internal processes being blamed on customers? I already canceled the card and still had an overpayment. Even your sales rep commented, “Why did you pay so much?” and reminded me to come and collect the surplus. Over a week later, I finally went to pick up my refund. How am I supposed to know the exact amount? You’re the ones looking at the screen and calculating, not me. UOB even transferred the surplus back to me. And now I’m still listed as owing money and overdue? How does that make sense? Read more
# 15289                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Activate card
# 15305                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Activate card
#
#       detected_lang sentiment
# 135              en  negative
# 136              en  negative
# 511              lb   neutral
# 512              lb   neutral
# 594              fr  negative
# 595              fr  negative
# 1183             fr  negative
# 1184             fr  negative
# 1207             fr  negative
# 1214             en   neutral
# 1219             fr  negative
# 1220             en   neutral
# 1759             en  positive
# 1761             en  positive
# 1941             en  negative
# 1942             en  negative
# 1958             uz   neutral
# 1960             uz   neutral
# 2453             id  negative
# 2454             id  negative
# 2553             ms  positive
# 2554             ms  positive
# 2571             en  positive
# 2572             en  positive
# 2664             en   neutral
# 2665             en   neutral
# 2721             en  positive
# 2722             en  positive
# 3017             en  positive
# 3036             id   neutral
# 3037             en   neutral
# 3049             en  positive
# 3056             en  positive
# 3063             en   neutral
# 3064             id   neutral
# 3067             en  positive
# 3069             en  positive
# 3071             id   neutral
# 3072             id   neutral
# 3073             en  positive
# 3074             en  positive
# 3076             id   neutral
# 3077             en  positive
# 3078             en  positive
# 3081             en  positive
# 3122             en  positive
# 3125             en  positive
# 3126             en  positive
# 3218             ms  positive
# 3227             ms  positive
# 3249             en  positive
# 3250             en  positive
# 3456             ms  positive
# 3630             ms  positive
# 3646             en  positive
# 3649             en  positive
# 4770             id  negative
# 4771             id  negative
# 4989             en  positive
# 5053             en  positive
# 5276             en  positive
# 5277             en  positive
# 5278             en  positive
# 5279             en  positive
# 5280             en  positive
# 5282             en  positive
# 5283             en  positive
# 5309             en   neutral
# 5310             en   neutral
# 5451             ms  negative
# 5460             ms  negative
# 5752             en   neutral
# 5753            hmn   neutral
# 5754             en   neutral
# 5755            hmn   neutral
# 5951             en  positive
# 5958             en  positive
# 5987             es  positive
# 6030             es  positive
# 6087             en   neutral
# 6089             en   neutral
# 6408             en  positive
# 6409             en  positive
# 6441             en   neutral
# 6453             en   neutral
# 7818             en   neutral
# 7822             en   neutral
# 7882             en  positive
# 7888             en  positive
# 8057             en  negative
# 8061             en  negative
# 8626             en  negative
# 8627             en  negative
# 8928             en  positive
# 8934             en  positive
# 8992             en  positive
# 8999             en  positive
# 9096             es   neutral
# 9097             es   neutral
# 9135             en   neutral
# 9137             en   neutral
# 9139             tr   neutral
# 9140             hi   neutral
# 9142             tr   neutral
# 9143             hi   neutral
# 9169             hi   neutral
# 9172             hi   neutral
# 9173             hi   neutral
# 9197             id  positive
# 9198             id  positive
# 9345             en  negative
# 9348             en  negative
# 10020            en  positive
# 10021            en  positive
# 10269            id   neutral
# 10294            id   neutral
# 10690            id   neutral
# 10691            id   neutral
# 10692            id   neutral
# 10693            id   neutral
# 12159            ms   neutral
# 12165            ms   neutral
# 12535            en  negative
# 12536            en  negative
# 12537            en  negative
# 12538            en  negative
# 12539            en  negative
# 12541            en  negative
# 12542            en  negative
# 12543            en  negative
# 12544            en  negative
# 12545            en  negative
# 12546            en  negative
# 12547            en  negative
# 12570            en  positive
# 12571            en  positive
# 12572            en  positive
# 12573            en  positive
# 12579            en  positive
# 12580            en  positive
# 12581            en  positive
# 12582            en  positive
# 12733            ms   neutral
# 12781            ms   neutral
# 12866            sw   neutral
# 12941            sw   neutral
# 14950            en  negative
# 14955            en  negative
# 15289            en   neutral
# 15305            en   neutral

# %% [markdown]
# ## Final form of COLLATE_COMMENT
# > Now COLLATE_COMMENT is in the best form, we can create the new database.

# %%
# Reading the file - unpickling
import pickle
import pandas as pd
with open('./Data/COLLATE/COMMENT_sentiment_deduplicated.pkl', 'rb') as fp:
    COLLATE_COMMENT = pickle.load(fp)
## Preview
print('COMMENT_Deduplicated')
display(pd.concat([ COLLATE_COMMENT.head(2),  COLLATE_COMMENT.tail(2) ]))
display(COLLATE_COMMENT.dtypes)
display(COLLATE_COMMENT.shape)
# Out:
# COMMENT_Deduplicated
#       Youtube_Video_IDs            poster_OP  comment_age  \
# 0           FmQz15WJkWE       @tinkerlee-r9z  3 weeks ago
# 1           zb3oKcLv1yA     @kayanemahberkah  1 month ago
# 15446       4tA8wtLaui4           @JokeRQuas  7 years ago
# 15447       gA0hQtE6TL4  @floristdahlins8520  9 years ago
#
#                                             full_comment  like_count  \
# 0      BECAREFUL WHAT YOU WISH FOR   -  CIRCUS   ???!...           0
# 1      kak cara pindahin ocbc mobile dari hp lama ke ...           0
# 15446                                                  .           0
# 15447                                                  ,           0
#
#       Youtube_Handle                                    translated_text  \
# 0       @channelocbc  BECAREFUL WHAT YOU WISH FOR   -  CIRCUS   ???!...
# 1       @channelocbc  Sis, how do I move OCBC Mobile from an old cel...
# 15446           @uob                                                  .
# 15447           @uob                                                  ,
#
#       detected_lang sentiment
# 0                en   neutral
# 1                id   neutral
# 15446            en   neutral
# 15447            en   neutral
# Youtube_Video_IDs    object
# poster_OP            object
# comment_age          object
# full_comment         object
# like_count            int64
# Youtube_Handle       object
# translated_text      object
# detected_lang        object
# sentiment            object
# dtype: object
# (15363, 9)

# %%
import sqlite3
import pandas as pd

# 🧩 assume you already have these DataFrames defined:
# ABM_table, Overview_table, MM_df, COMMENT_df

# ----------------------------------------------------
# 1️⃣ Connect to database (creates youtube_data.db if not exists)
# ----------------------------------------------------
conn = sqlite3.connect("./Data/RDBMS/malaysian_youtube_banks_sentiment_deduplicated.db")
cursor = conn.cursor()

# Always enable foreign key enforcement in SQLite
cursor.execute("PRAGMA foreign_keys = ON;")

# ----------------------------------------------------
# 2️⃣ Define schema (drop old tables and recreate)
# ----------------------------------------------------
schema_script = """
PRAGMA foreign_keys = ON;

DROP TABLE IF EXISTS COMMENT_table;
DROP TABLE IF EXISTS MM_table;
DROP TABLE IF EXISTS Overview_table;
DROP TABLE IF EXISTS ABM_table;

CREATE TABLE ABM_table (
    Bank_Names TEXT,
    Hashtag_Name TEXT,
    Top_Person TEXT,
    Top_Title TEXT,
    Bank_Website TEXT,
    Youtube_Handle TEXT PRIMARY KEY
);

CREATE TABLE Overview_table (
    ID TEXT PRIMARY KEY,
    mail TEXT,
    Scraped_DateTime DATETIME,
    phone TEXT,
    language TEXT,
    privacy_public TEXT,
    info_outline TEXT,
    person_radar TEXT,
    my_videos TEXT,
    Videos_Not_Shorts INTEGER,
    trending_up TEXT,
    FOREIGN KEY (ID) REFERENCES ABM_table (Youtube_Handle)
);

CREATE TABLE MM_table (
    Youtube_Video_IDs TEXT PRIMARY KEY,
    Youtube_Handle TEXT NOT NULL,
    video_length INTEGER,   -- should already be converted to seconds
    views REAL,
    date DATETIME,
    title TEXT,
    likes REAL,
    description TEXT,
    MM_timestamp DATETIME,
    is_commented TEXT,
    FOREIGN KEY (Youtube_Handle) REFERENCES ABM_table (Youtube_Handle)
);

CREATE TABLE COMMENT_table (
    Youtube_Video_IDs TEXT NOT NULL,
    Youtube_Handle TEXT,
    poster_OP TEXT,
    comment_age TEXT,
    full_comment TEXT,
    like_count INTEGER,
    translated_text TEXT,
    detected_lang TEXT,
    sentiment TEXT,
    FOREIGN KEY (Youtube_Video_IDs) REFERENCES MM_table (Youtube_Video_IDs)
);
"""

cursor.executescript(schema_script)
print("✅ Tables created successfully.")

# ----------------------------------------------------
# 3️⃣ Insert data into tables (in dependency order)
# ----------------------------------------------------
# Each to_sql() appends data to the pre-defined schema.
# index=False prevents adding an unnecessary index column.

abm_banks_df.to_sql("ABM_table", conn, if_exists="append", index=False)
overview_df.to_sql("Overview_table", conn, if_exists="append", index=False)
COLLATE_MM.to_sql("MM_table", conn, if_exists="append", index=False)
COLLATE_COMMENT.to_sql("COMMENT_table", conn, if_exists="append", index=False)

print("✅ DataFrames inserted successfully.")

# ----------------------------------------------------
# 4️⃣ Commit changes and close connection
# ----------------------------------------------------
conn.commit()
conn.close()

print("💾 Database committed and connection closed.")
# Out:
# ✅ Tables created successfully.
# ✅ DataFrames inserted successfully.
# 💾 Database committed and connection closed.

# %% [markdown]
# # SQL-to-Text Agent

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.utilities import SQLDatabase
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint, HuggingFacePipeline

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
db = SQLDatabase.from_uri("sqlite:///./Data/RDBMS/malaysian_youtube_banks.db", sample_rows_in_table_info=0)

def get_schema(_):
    return db.get_table_info()


def run_query(query):
    print(f'Query being run: {query} \n\n')
    return db.run(query)

# %%
print(get_schema(''))
# Out:
# CREATE TABLE "ABM_table" (
# 	"Bank_Names" TEXT,
# 	"Hashtag_Name" TEXT,
# 	"Top_Person" TEXT,
# 	"Top_Title" TEXT,
# 	"Bank_Website" TEXT,
# 	"Youtube_Handle" TEXT,
# 	PRIMARY KEY ("Youtube_Handle")
# )
#
#
# CREATE TABLE "COMMENT_table" (
# 	"Youtube_Video_IDs" TEXT NOT NULL,
# 	"Youtube_Handle" TEXT,
# 	"poster_OP" TEXT,
# 	comment_age TEXT,
# 	full_comment TEXT,
# 	like_count INTEGER,
# 	FOREIGN KEY("Youtube_Video_IDs") REFERENCES "MM_table" ("Youtube_Video_IDs")
# )
#
#
# CREATE TABLE "MM_table" (
# 	"Youtube_Video_IDs" TEXT,
# 	"Youtube_Handle" TEXT NOT NULL,
# 	video_length INTEGER,
# 	views REAL,
# 	date DATETIME,
# 	title TEXT,
# 	likes REAL,
# 	description TEXT,
# 	"MM_timestamp" DATETIME,
# 	is_commented TEXT,
# 	PRIMARY KEY ("Youtube_Video_IDs"),
# 	FOREIGN KEY("Youtube_Handle") REFERENCES "ABM_table" ("Youtube_Handle")
# )
#
#
# CREATE TABLE "Overview_table" (
# 	"ID" TEXT,
# 	mail TEXT,
# 	"Scraped_DateTime" DATETIME,
# 	phone TEXT,
# 	language TEXT,
# 	privacy_public TEXT,
# 	info_outline TEXT,
# 	person_radar TEXT,
# 	my_videos TEXT,
# 	"Videos_Not_Shorts" INTEGER,
# 	trending_up TEXT,
# 	PRIMARY KEY ("ID"),
# 	FOREIGN KEY("ID") REFERENCES "ABM_table" ("Youtube_Handle")
# )

# %%
def get_llm(load_from_hugging_face=False):
    if load_from_hugging_face:
        api_key = os.environ.get("OPENROUTER_API_KEY")
        if not api_key:
            raise ValueError("Missing HYPERBOLIC_API_KEY environment variable.")
            print(f"✅ Loaded API key: {api_key[:5]}... (length: {len(api_key)})")
        llm = HuggingFaceEndpoint(
            repo_id="Qwen/Qwen2.5-VL-7B-Instruct",
            task="text-generation",
            provider="hyperbolic",  # set your provider here
            api_key=api_key,  # ✅ add this line
        )

        return ChatHuggingFace(llm=llm)
    
    return ChatOpenAI(model="gpt-4o", temperature=0.0)


def write_sql_query(llm):
    template = """Based on the table schema below, write a SQL query that would answer the user's question:
    {schema}

    Question: {question}
    SQL Query:"""

    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "Given an input question, convert it to a SQL query. No pre-amble. "
            "Please do not return anything else apart from the SQL query, no prefix aur suffix quotes, no sql keyword, nothing please"),
            ("human", template),
        ]
    )

    return (
        RunnablePassthrough.assign(schema=get_schema)
        | prompt
        | llm
        | StrOutputParser()
    )

# %%
def answer_user_query(query, llm):
    template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
    {schema}

    Question: {question}
    SQL Query: {query}
    SQL Response: {response}"""

    prompt_response = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "Given an input question and SQL response, convert it to a natural language answer. No pre-amble.",
            ),
            ("human", template),
        ]
    )

    full_chain = (
        RunnablePassthrough.assign(query=write_sql_query(llm))
        | RunnablePassthrough.assign(
            schema=get_schema,
            response=lambda x: run_query(x["query"]),
        )
        | prompt_response
        | llm
    )

    return full_chain.invoke({"question": query})

# %%
# write_sql_query(llm=get_llm(load_from_hugging_face=True)).invoke({"question": "Give me 10 Artists"})
query = 'Give some Youtube_Video IDs from AmBank youtube channel. Refer'
response = answer_user_query(query, llm=get_llm(load_from_hugging_face=False))
print(response.content)
# Out:
# Query being run: SELECT MM_table.Youtube_Video_IDs
# FROM MM_table
# JOIN ABM_table ON MM_table.Youtube_Handle = ABM_table.Youtube_Handle
# WHERE ABM_table.Bank_Names = 'AmBank'
#
#
# There are no YouTube video IDs available from the AmBank YouTube channel in the database.

# %% [markdown]
# ### Check if api key is active

# %%
import requests, os
from dotenv import load_dotenv
key = os.environ.get("HYPERBOLIC_API_KEY")
r = requests.get("https://api.hyperbolic.xyz/v1/models", headers={"Authorization": f"Bearer {key}"})
print(r.status_code, r.text)
# Out:
# 200 {"object":"list","data":[{"id":"Qwen/Qwen2.5-72B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131072,"input_price":0.4,"output_price":0.4},{"id":"meta-llama/Meta-Llama-3-70B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":8192,"input_price":0.4,"output_price":0.4},{"id":"deepseek-ai/DeepSeek-V3","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131072,"input_price":0.25,"output_price":0.25},{"id":"deepseek-ai/DeepSeek-V3-0324","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":163840,"input_price":1.25,"output_price":1.25},{"id":"meta-llama/Llama-3.3-70B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131072,"input_price":0.4,"output_price":0.4},{"id":"Qwen/Qwen2.5-Coder-32B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":32768,"input_price":0.2,"output_price":0.2},{"id":"meta-llama/Llama-3.2-3B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131072,"input_price":0.1,"output_price":0.1},{"id":"NousResearch/Hermes-3-Llama-3.1-70B","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":12288,"input_price":0.4,"output_price":0.4},{"id":"meta-llama/Meta-Llama-3.1-405B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131000,"input_price":4.0,"output_price":4.0},{"id":"meta-llama/Meta-Llama-3.1-70B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131072,"input_price":0.4,"output_price":0.4},{"id":"meta-llama/Meta-Llama-3.1-8B-Instruct","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":131072,"input_price":0.1,"output_price":0.1},{"id":"meta-llama/Meta-Llama-3.1-405B","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":32768,"input_price":2.0,"output_price":2.0},{"id":"deepseek-ai/DeepSeek-R1","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":163840,"input_price":2.0,"output_price":2.0},{"id":"deepseek-ai/DeepSeek-R1-0528","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false,"context_length":163840,"input_price":3.0,"output_price":3.0},{"id":"Qwen/QwQ-32B","created":1762682100,"object":"model","owned_by":"Hyperbolic","number_of_inference_nodes":null,"supports_chat":true,"supports_image_input":false,"supports_tools":false ...

# %% [markdown]
# ## Putting it all together

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.utilities import SQLDatabase
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint, HuggingFacePipeline

from dotenv import load_dotenv
load_dotenv()

db = SQLDatabase.from_uri("sqlite:///./Data/RDBMS/malaysian_youtube_banks.db", sample_rows_in_table_info=0)

def get_schema(_):
    return db.get_table_info()


def run_query(query):
    print(f'Query being run: {query} \n\n')
    return db.run(query)

print(get_schema(''))


def get_llm(load_from_hugging_face=False):
    if load_from_hugging_face:
        api_key = os.environ.get("OPENROUTER_API_KEY")
        if not api_key:
            raise ValueError("Missing HYPERBOLIC_API_KEY environment variable.")
            print(f"✅ Loaded API key: {api_key[:5]}... (length: {len(api_key)})")
        llm = HuggingFaceEndpoint(
            repo_id="Qwen/Qwen2.5-VL-7B-Instruct",
            task="text-generation",
            provider="hyperbolic",  # set your provider here
            api_key=api_key,  # ✅ add this line
        )

        return ChatHuggingFace(llm=llm)
    
    return ChatOpenAI(model="gpt-4o", temperature=0.0)


def write_sql_query(llm):
    template = """Based on the table schema below, write a SQL query that would answer the user's question:
    {schema}

    Question: {question}
    SQL Query:"""

    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "Given an input question, convert it to a SQL query. No pre-amble. "
            "Please do not return anything else apart from the SQL query, no prefix aur suffix quotes, no sql keyword, nothing please"),
            ("human", template),
        ]
    )

    return (
        RunnablePassthrough.assign(schema=get_schema)
        | prompt
        | llm
        | StrOutputParser()
    )


def answer_user_query(query, llm):
    template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
    {schema}

    Question: {question}
    SQL Query: {query}
    SQL Response: {response}"""

    prompt_response = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "Given an input question and SQL response, convert it to a natural language answer. No pre-amble.",
            ),
            ("human", template),
        ]
    )

    full_chain = (
        RunnablePassthrough.assign(query=write_sql_query(llm))
        | RunnablePassthrough.assign(
            schema=get_schema,
            response=lambda x: run_query(x["query"]),
        )
        | prompt_response
        | llm
    )

    return full_chain.invoke({"question": query})

# import os
# os.environ
# Out:
# CREATE TABLE "ABM_table" (
# 	"Bank_Names" TEXT,
# 	"Hashtag_Name" TEXT,
# 	"Top_Person" TEXT,
# 	"Top_Title" TEXT,
# 	"Bank_Website" TEXT,
# 	"Youtube_Handle" TEXT,
# 	PRIMARY KEY ("Youtube_Handle")
# )
#
#
# CREATE TABLE "COMMENT_table" (
# 	"Youtube_Video_IDs" TEXT NOT NULL,
# 	"Youtube_Handle" TEXT,
# 	"poster_OP" TEXT,
# 	comment_age TEXT,
# 	full_comment TEXT,
# 	like_count INTEGER,
# 	FOREIGN KEY("Youtube_Video_IDs") REFERENCES "MM_table" ("Youtube_Video_IDs")
# )
#
#
# CREATE TABLE "MM_table" (
# 	"Youtube_Video_IDs" TEXT,
# 	"Youtube_Handle" TEXT NOT NULL,
# 	video_length INTEGER,
# 	views REAL,
# 	date DATETIME,
# 	title TEXT,
# 	likes REAL,
# 	description TEXT,
# 	"MM_timestamp" DATETIME,
# 	is_commented TEXT,
# 	PRIMARY KEY ("Youtube_Video_IDs"),
# 	FOREIGN KEY("Youtube_Handle") REFERENCES "ABM_table" ("Youtube_Handle")
# )
#
#
# CREATE TABLE "Overview_table" (
# 	"ID" TEXT,
# 	mail TEXT,
# 	"Scraped_DateTime" DATETIME,
# 	phone TEXT,
# 	language TEXT,
# 	privacy_public TEXT,
# 	info_outline TEXT,
# 	person_radar TEXT,
# 	my_videos TEXT,
# 	"Videos_Not_Shorts" INTEGER,
# 	trending_up TEXT,
# 	PRIMARY KEY ("ID"),
# 	FOREIGN KEY("ID") REFERENCES "ABM_table" ("Youtube_Handle")
# )

# %% [markdown]
# ## Invoke

# %%
# write_sql_query(llm=get_llm(load_from_hugging_face=True)).invoke({"question": "Give me 10 Artists"})
query = 'Give some Youtube IDs from @AmBankTV youtube channel'
# query = 'What is the most liked Youtube_Handle? What is the like count?'
response = answer_user_query(query, llm=get_llm(load_from_hugging_face=False))
print(response.content)
# Out:
# Query being run: SELECT "Youtube_Video_IDs" FROM "MM_table" WHERE "Youtube_Handle" = '@AmBankTV'
#
#
# Here are some YouTube video IDs from the @AmBankTV YouTube channel: p7bPO1SfHJc, xceiS_r8WlQ, s9pNJYzRvxs, FPGhDYBIlVw, obl5r-aOqy4, sh0XVQDBBsY, -EmdeyJqKs0, lyUjdro80JU, Og6vcBivg9s, iWlD8iSavE8, Gxqo6ATyNRk, dakhg2Y5dmA, NuvL9E1tj78, DQoAgLVNmQQ, m6vp8iRZQho, v0fGb5HYdj8, 1CuoWYO4g3A, 8R-PJGUtckQ, kUaME0yWLlk, Ingpxi2P9l4, NHjDiHutLI8, QS-qG6qjK0c, pgOf1fNtBFM, DneKHHrKTjg, Ucridpq3AE8, n0BI-kBRPE8, GXsRutMMGyk, 9mOg79iCBvo, TIaFNvG9d_s, xuVsf7ViE80, zCHrjR2eRt0&pp=0gcJCQYKAYcqIYzv, ngG-L1P8yB8, 6PK-YB5cd6I, 6buWnO2MHR0, O7lsF5QIUoE, pQkm_E0MbC4, 4NIUwMTwHKQ, dvXU7IcXiaQ, ySvLzc903NI, vVVF4u4aBF8, y86BUfJJ6F8, nB_SGdsekEs, ATZXj7DNUM0&pp=0gcJCQYKAYcqIYzv, zn_1LtSBb9M, VYLfZXt6eI8, bQTveY0KRwk, ckXP_hL6ONs, 7dJcjmjhW0k, tfPe0ZGIDQE, BuppOchl91w, vL0E86l40pE, LiC4rIiZwLM, pjWz2AVxcQs, 2wsiMY-Se6c, cnEzC8kAPBo, -Owb2J300s4, kG7LUO_LQQ0, hR5EbQ7TvIQ, d-TnDKkWYLk, uQKdMhvKUmU, JV3s5I2kadY, gXv6Xey6Wsk, S25TyE0cZt4, gZsRz_8wtEA, izDAbDXI3t8, e-WPbYoFB5s, cH6kHWdHLIg, SjxEQaedBmo, Tbtr3zJWYgs, IQxI11Hod0o, sXF_gucOWlQ, d68PBkqJelg, D9zhZN24AKc&pp=0gcJCQYKAYcqIYzv, Na5kpeqrUe8, 3dRRQjfA--0, kBk7ldfdf4A, xiJLBRQzfbQ, 4GvNoEaS-qM&pp=0gcJCQYKAYcqIYzv, i4HreG-tJ2s, U8w3wqwxLy0, rjJXDGXcqeY, h28A9zLBMQA, FPo3hTp8q9g, n-gD_1Xg3LY, UXNaNuZnx50, pG5pwjrTUck, BY5ee1rDma8, Dh5GU58R9C0&pp=0gcJCQYKAYcqIYzv, dFuvqkpFGbc&pp=0gcJCQYKAYcqIYzv, 4coYy3OcXDc, MwxKkMmnFt4, JB4UJ2t2ES8, 6VbLjjkbwqY&pp=0gcJCQYKAYcqIYzv, LH4d7k4831o&pp=0gcJCQYKAYcqIYzv, vFRGH3bOuS4, 6GufVDTyqjU, qf4fRFiSWz0, v-egEiAEhUI, _MoagBDa6RI, wdax0aeLIhA, xvfwbbl8KZU, HAki1lW_xMQ, waU9CacQqRw, -yzdx1YX4_U, cxaio853J5Y&pp=0gcJCQYKAYcqIYzv, q_bUPrRdQAg, X9k0KpAhVLk, uSzixdL2F4w, bj49k4rYKfY, OzM5mxgfZ0o, 2SOsO6CvOzU, 5KnFHIz0qYA, lOgfJ6Ow0LE, NjhjLfHyNhU, HYd1YQIDAd0, fXhc82j-ufQ, 5Eb6Jx7J-yU, a87TDvTHYfY, a7Vz4C_O_bw, 8RW2qQ6Vges, JNTYOMpb-Z4, Itudm0enH74, FMrVn1OSAm8, mI3BrQuj7E4&pp=0gcJCQYKAYcqIYzv, DaT46afkGx8, zvAiOAamkL8, qTQNqdOHDzI, YcXWIV3tWXA, 3HaaDoej7BY, pINIdLK0oYY&pp=0gcJCQYKAYcqIYzv, 87Oh9x0ZUEc, xjr2_MzAB38, mIrcT0BxPJ0, OMEs8CivPZQ, Yj7UmlUktsQ, wHbrXlfFM34, UMA-dZe9cnw, Fx7qJbM4i70, RupRRDN8mdc, TI4ARcUCeRg, c1JF8RcARvM, 2dgFFQHyl6c&pp=0gcJCQYKAYcqIYzv, zk_FS8AE5yY, J1HYJYf-7I8, p16af1vO_Jg, rmvvuqn38XA, RWghDBFep8k, 3pN9EXaPeo8, yJ3fvs6LqME, fP3sHzynWws, XX8K9my8k0s&pp=0gcJCQYKAYcqIYzv, XYbtL9DjHTI, nk2jbiiuUdo, QdCHs-AWRgg, gN-EGe5dBsE, UBCrSPxtgVA, uJc1N0-duH8, V--2nYlpJ5s, nerGhHkQJJ8, RWI-poEhszY, 8YjG-deQeYs, HfcGjewnItY, vXKwmBbx2K0, Ou00eqhOC4k, NuBoWhFGvDo, 4H8yBVIT8pM, uLN8zfpsPus&pp=0gcJCQYKAYcqIYzv, ziVSREGZFNU&pp=0gcJCQYKAYcqIYzv, VaeqT9NSb4Q, 889Pyw3SLd4, 0cj4f0gsB2Q, dRK74l4E1FM, Yd6NNpn1A84&pp=0gcJCQYKAYcqIYzv, 7S2l29C9GSA, 5k_by6h_VPY, Rf_ur5K8Kbk, PvUItDK0e24, CTDNaifzcQI&pp=0gcJCQYKAYcqIYzv, VATTxYeP604, t_kGumBPKcY, yyzyTvFrV8Y, hb6l_KAv_NY, TYRr0fFubY0, ydPEePpHvDI, y6rNx0kxOgk, BLmy-VU3vps, k6w86vkYX-c, MHVB76_bmkE, m6_IH35upoM, SzsOCY2bNGQ, s2swjHMKSfI, qyFd1Ee2ikE, E9uYk1FU6mQ, UWIoGA6bGAg, kWR2tBAwlcA, vyDc1UlNRi0&pp=0gcJCQYKAYcqIYzv, RGygQ9OW_6o, 7wacGkQznOk&pp=0gcJCQYKAYcqIYzv, YWuqoIrPFtU, bFyD-TiM8C8, 3sTuNYYxjRY, zHXR8IBepyc, XKkw-l0oA8g, 4vRaEKS4xx8, wNjNrQZIags, u30nxRDkNB4, K8_RfUa8dUI, 7S3oH50cWJE, Fi1URfDZwaE, obqqY0ZIG2g, jJsQkx2i9HI, eaC1KQeDPVg, 7oaha-r6b80, skAlWUdnYtc, WdE-pRWerEk, EQOUwF9RmU0, dcNyFHCib9I, ozhJDqwY4DE, IquYLcteuM4, HKMuDmMUrAw, HysbFEUga-8, iRP6tggCUMM, aLHRywvIKqg, DH6GdNvX540, 0bi7KuNyn2o, Ns6D8IbgUEA, 0xzAk5QfDCg, IIDn78kPwx4&pp=0gcJCQYKAYcqIYzv, KGGQXIpXDuI, 5OZ2gdXO0zE, 30WqZn5Zm54, sBNCA1x_zdM, EZom8jZkoxI, 2w0iK4Al4CY, T0NlKoMsXMY, WiW0SuxtlBM, 8XJ5FSdowTs, 2OE5LLVDGC4, y8yPuGV73Js, 2R3sBSehfbk, YAOlptwRqIM, -LEQn1zbowE, smQBmtvRbbQ, zBEPWIww96I, D1-w7KnkIKw, iRKvENCv3kA, k3kdz419Q3k, BuliONOKMso, jmmN-vqrZb4, 4c3WhJcgp8g&pp=0gcJCQYKAYcqIYzv, NuRU6iZHMRI, uLTK1D4Pszw&pp=0gcJCQYKAYcqIYzv, jlpfUC2oMc0, S_g3-iDjgDw, 9m-7xsb_yww, 8afPN01kaYE, qtFgSgXyvtk, RQr0Zdz29RY&pp=0gcJCQYKAYcqIYzv, sRZXFmfR8xQ, MCsP7AW6r-M, 683P_ley5n4, -YVfGLI1ZSI, xZlOtTAfeaM, ZTpQswp-jGU, BdH5Ni8Gbao, K2BgIXJpQvA&pp=0gcJCQYKAYcq ...

# %% [markdown]
# ## Appendix

# %%
## Postive test cases
query1 = "What is the most viewed video in MM_table? What is the video title and video_ID?"
query2 = 'Are there any repeated poster_OPs across Youtube_Handles within the COMMENT_table?'

# %%
import re
string  = """
SELECT MM_table.title, COUNT(COMMENT_table.sentiment) AS negative_comment_count, MM_table.likes
FROM MM_table
JOIN COMMENT_table ON MM_table.Youtube_Video_IDs = COMMENT_table.Youtube_Video_IDs
WHE;"""

sql_match = re.search(r"SELECT.*?;", string, re.IGNORECASE | re.DOTALL | re.MULTILINE)

sql_match.group(0).strip()
# Out:
# 'SELECT MM_table.title, COUNT(COMMENT_table.sentiment) AS negative_comment_count, MM_table.likes\nFROM MM_table\nJOIN COMMENT_table ON MM_table.Youtube_Video_IDs = COMMENT_table.Youtube_Video_IDs\nWHE;'

# %%
COLLATE_COMMENT.groupby(['Youtube_Handle', 'sentiment']).agg(col_1=pd.NamedAgg(column='sentiment', aggfunc='count')).loc['@AFFIN',:]
# Out:
#            col_1
# sentiment
# negative     165
# neutral       96
# positive     319

# %%
COLLATE_COMMENT.columns
# Out:
# Index(['Youtube_Video_IDs', 'poster_OP', 'comment_age', 'full_comment',
#        'like_count', 'Youtube_Handle', 'translated_text', 'detected_lang',
#        'sentiment'],
#       dtype='object')

# %%
data = [('LiFxYCLSvb4&pp=0gcJCQYKAYcqIYzv', '@channelocbc', '1:07', 90.0, '2025-10-15 00:00:00', 'OCBC Structured Notes: Customise Your Risk and Gains to Your Investment Appetite', 3.0, 'Enjoy the flexibility of attaining exposure to assets without direct ownership of it. Choose from a wide range of assets including interest rates, foreign exchange rates, equities, market indices, credit, commodity prices.', '2025-11-02 22:59:13', '0'), ('N9SBRNEAnhI', '@channelocbc', '2:11', 514.0, '2025-10-10 00:00:00', 'OCBC - Banking on Us - Episode 1', 16.0, 'While the city sleeps, our teams are wide awake.\n\nEpisode 1 of Banking on Us takes you into the world of Scheduled Maintenance, a regular but critical operation that keeps us strong, secure and ready.\n\n🎬 Watch the full story and meet the people working tirelessly behind the scenes.', '2025-11-02 22:59:33', '0'), ('PLqT8W6JNDY', '@channelocbc', '1:47', 104.0, '2025-10-03 00:00:00', 'OCBC One Connect - Integrated Ecosystem Support (China-Indonesia)', 1.0, 'OCBC One Connect - Integrated Ecosystem Support (China-Indonesia)', '2025-11-02 22:59:52', '0'), ('4UBrl92xXOU', '@channelocbc', '1:59', 79932.0, '2025-10-01 00:00:00', 'Behind the scenes of our 2025 brand campaign – Purpose is about lifting others.', 7.0, 'Watch how our latest brand campaign stories get put together, through the sharing of inspiring tales of four individuals from Singapore, Hong Kong, Indonesia, and Malaysia - Each one of them bravely pursuing their dreams and transforming the lives of countless others in the process.\n\nPurpose...', '2025-11-02 23:00:12', '0'), ('cYtlA9Q7UAo', '@channelocbc', '4:18', 178.0, '2025-09-30 00:00:00', 'OCBC華僑銀行市場熱點: 預期今年減息三次 (22-09-2025)', 2.0, 'OCBC華僑銀行財富管理專家團隊預期，美國就業數據疲弱，將促使聯儲局加快減息，預期聯儲局將於9月、10月和12月各減息25個基點，合共減息三次，2025年底聯邦基金利率將降至3.50%-3.75%，聯儲局重啟減息將為金融市場注入新動力。', '2025-11-02 23:00:32', '0')]
pd.DataFrame(data)
# Out:
#                                  0             1     2        3  \
# 0  LiFxYCLSvb4&pp=0gcJCQYKAYcqIYzv  @channelocbc  1:07     90.0
# 1                      N9SBRNEAnhI  @channelocbc  2:11    514.0
# 2                      PLqT8W6JNDY  @channelocbc  1:47    104.0
# 3                      4UBrl92xXOU  @channelocbc  1:59  79932.0
# 4                      cYtlA9Q7UAo  @channelocbc  4:18    178.0
#
#                      4  \
# 0  2025-10-15 00:00:00
# 1  2025-10-10 00:00:00
# 2  2025-10-03 00:00:00
# 3  2025-10-01 00:00:00
# 4  2025-09-30 00:00:00
#
#                                                                                   5  \
# 0  OCBC Structured Notes: Customise Your Risk and Gains to Your Investment Appetite
# 1                                                  OCBC - Banking on Us - Episode 1
# 2                 OCBC One Connect - Integrated Ecosystem Support (China-Indonesia)
# 3   Behind the scenes of our 2025 brand campaign – Purpose is about lifting others.
# 4                                               OCBC華僑銀行市場熱點: 預期今年減息三次 (22-09-2025)
#
#       6  \
# 0   3.0
# 1  16.0
# 2   1.0
# 3   7.0
# 4   2.0
#
#                                                                                                                                                                                                                                                                                                            7  \
# 0                                                                             Enjoy the flexibility of attaining exposure to assets without direct ownership of it. Choose from a wide range of assets including interest rates, foreign exchange rates, equities, market indices, credit, commodity prices.
# 1             While the city sleeps, our teams are wide awake.\n\nEpisode 1 of Banking on Us takes you into the world of Scheduled Maintenance, a regular but critical operation that keeps us strong, secure and ready.\n\n🎬 Watch the full story and meet the people working tirelessly behind the scenes.
# 2                                                                                                                                                                                                                                          OCBC One Connect - Integrated Ecosystem Support (China-Indonesia)
# 3  Watch how our latest brand campaign stories get put together, through the sharing of inspiring tales of four individuals from Singapore, Hong Kong, Indonesia, and Malaysia - Each one of them bravely pursuing their dreams and transforming the lives of countless others in the process.\n\nPurpose...
# 4                                                                                                                                                                                     OCBC華僑銀行財富管理專家團隊預期，美國就業數據疲弱，將促使聯儲局加快減息，預期聯儲局將於9月、10月和12月各減息25個基點，合共減息三次，2025年底聯邦基金利率將降至3.50%-3.75%，聯儲局重啟減息將為金融市場注入新動力。
#
#                      8  9
# 0  2025-11-02 22:59:13  0
# 1  2025-11-02 22:59:33  0
# 2  2025-11-02 22:59:52  0
# 3  2025-11-02 23:00:12  0
# 4  2025-11-02 23:00:32  0
